# %%
import matplotlib.pyplot as plt
from tqdm import * #progress bar
from sccm import CryptoCurrencyModel
from sccm.agents import *

# %%
model = CryptoCurrencyModel(0)
model.add_agent(Miner, 100., 100)
model.add_agent(RandomTrader, 10., 200)
model.add_agent(Chartist, 1., 20)

# %%
#%%prun -s cumulative
for i in tqdm(range(10000)): #todo use batch runner from mesa for MC sim
    model.step()
# Out:
# 100%|██████████| 10000/10000 [00:26<00:00, 377.69it/s]

# %%
gini = model.datacollector.get_model_vars_dataframe()
gini.plot()
plt.show()
